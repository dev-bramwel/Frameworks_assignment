# %%
#import libraries
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# import data from dataset
df = pd.read_csv('metadata_sample.csv')
print("Data loaded successfully")
print("Begin data cleaning")
# Out:
# Data loaded successfully
# Begin data cleaning

# %%
# data cleaning
#get a snapshot of the data
print ("The following is some information about the data✅\n")
print(df.info()) #generate an informatory description about the data
print("\nHere are the first 10 rows💲\n")
print(df.head()) # show the first 5 rows
print ("\nThis is a descriptive summary📊\n")
print(df.describe())
# Out:
# The following is some information about the data✅
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cord_uid      10 non-null     object
#  1   title         10 non-null     object
#  2   abstract      10 non-null     object
#  3   publish_time  10 non-null     object
#  4   authors       10 non-null     object
#  5   journal       10 non-null     object
#  6   source_x      10 non-null     object
# dtypes: object(7)
# memory usage: 692.0+ bytes
# None
#
# Here are the first 10 rows💲
#
#   cord_uid                                     title  \
# 0     uid1            COVID-19 and its global impact
# 1     uid2          SARS-CoV-2 transmission dynamics
# 2     uid3       Vaccination strategies in pandemics
# 3     uid4  Mental health challenges during COVID-19
# 4     uid5             Long-term effects of COVID-19
#
# ...

# %%
#Analysing the data
print("Begin data analysis\n1️⃣ total records")
#Get total records
print(f"Total Records: {len(df)}")
#Group by time in years
print("\n2️⃣Grouping in years")
df['year'] = pd.to_datetime(df['publish_time']).dt.year
grouped = df.groupby('year')
print(grouped.size())
# List all unique values in 'source_x' and their counts
print("\n3️⃣Listing all sources")
source_counts = df['source_x'].value_counts()
print(source_counts)
# Select rows from a specific source
print("\n4️⃣Grouping data with same source")
selected_source = 'Elsevier'
rows_from_source = df[df['source_x'] == selected_source]
print(rows_from_source)
# Out:
# Begin data analysis
# 1️⃣ total records
# Total Records: 10
#
# 2️⃣Grouping in years
# year
# 2019    1
# 2020    5
# 2021    4
# dtype: int64
#
# 3️⃣Listing all sources
# source_x
# Elsevier     4
# Springer     2
# BMJ Group    1
# AMA          1
# AAAS         1
# Wiley        1
# Name: count, dtype: int64
#
# 4️⃣Grouping data with same source
#   cord_uid                                title  \
# 0     uid1       COVID-19 and its global impact
# 2     uid3  Vaccination strategies in pandemics
# 5     uid6             Modeling epidemic spread
# 9    uid10   Economic consequences of lockdowns
#
#                                             abstract publish_time  authors  \
# 0  This study explores the global impact of COVID...   2020-03-15  Smith J
# 2  Vaccination remains a key strategy to prevent ...   2021-01-05  Patel R
# 5  Epidemiological models help predict pandemic s...   2019-12-30   Wang L
# 9  Lockdowns have had significant economic impact...   2021-06-10   Khan F
#
# ...

# %%
#Visualization
print("The following is the visualization of the data on the frequency of each source\n")
# Get counts of each source
source_counts = df['source_x'].value_counts()

# Plot bar chart
plt.figure(figsize=(10,6))
source_counts.plot(kind='bar')
plt.title('Frequency of Each Source')
plt.xlabel('Source')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("\nA line graph showing how many studies were published yearly\n")
# line graph showing the studies pubished in each year
df['year'] = pd.to_datetime(df['publish_time']).dt.year

# Count rows per year
year_counts = df['year'].value_counts().sort_index()

# Plot line graph
plt.figure(figsize=(10,6))
plt.plot(year_counts.index, year_counts.values, marker='o')
plt.title('Number of Rows Published Each Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# The following is the visualization of the data on the frequency of each source
# A line graph showing how many studies were published yearly
